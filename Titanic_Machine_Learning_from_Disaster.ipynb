# %% [markdown]
# <a href="https://colab.research.google.com/github/akhilesh2009/Analysing-pharmaceutical-sales-data/blob/main/Titanic_Machine_Learning_from_Disaster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Titanic - Machine Learning from Disaster**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("/content/drive/MyDrive/train.csv")
